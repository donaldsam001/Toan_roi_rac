# %%
A = {1, 2, 3}
B = {3, 4}
C = {'x', 'y'}

# A x B Cách 1
[(a, b) for a in A for b in B]
# Out:
# [(1, 3), (1, 4), (2, 3), (2, 4), (3, 3), (3, 4)]

# %%
import itertools

# A x B Cách 2
list(itertools.product(A, B))
# Out:
# [(1, 3), (1, 4), (2, 3), (2, 4), (3, 3), (3, 4)]

# %%
[(a, b) for a in A for b in A] # A^2 cách 1
# Out:
# [(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)]

# %%
list ( itertools . product (A, repeat =2) ) # A^2 cách 2
# Out:
# [(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)]

# %%
# A x B x C cách 1
[(a, b, c) for a in A for b in B for c in C]
# Out:
# [(1, 3, 'x'),
#  (1, 3, 'y'),
#  (1, 4, 'x'),
#  (1, 4, 'y'),
#  (2, 3, 'x'),
#  (2, 3, 'y'),
#  (2, 4, 'x'),
#  (2, 4, 'y'),
#  (3, 3, 'x'),
#  (3, 3, 'y'),
#  (3, 4, 'x'),
#  (3, 4, 'y')]

# %%
# cách 2
list ( itertools . product (A, B, C) )
# Out:
# [(1, 3, 'x'),
#  (1, 3, 'y'),
#  (1, 4, 'x'),
#  (1, 4, 'y'),
#  (2, 3, 'x'),
#  (2, 3, 'y'),
#  (2, 4, 'x'),
#  (2, 4, 'y'),
#  (3, 3, 'x'),
#  (3, 3, 'y'),
#  (3, 4, 'x'),
#  (3, 4, 'y')]
