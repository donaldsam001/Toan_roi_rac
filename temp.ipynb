# %%
import numpy as np

# %%
so = 107
nhi_phan = np.binary_repr(so)
nhi_phan
# Out:
# '1101011'

# %%
m = 187
x = 172
p=1

# %%
for i in nhi_phan:
    print('\n')

    print(i, end='_____')
    p = p**2
    print(p, end='___')
    p = p % m
    print(p, end='___')
    if i == '1':
        p = p*x
        print(p, end='___')
    p = p % m
    print(p, end='___')
# Out:
# 1_____1___1___172___172___
#
# 1_____29584___38___6536___178___
#
# 0_____31684___81___81___
#
# 1_____6561___16___2752___134___
#
# 0_____17956___4___4___
#
# 1_____16___16___2752___134___
#
# 1_____17956___4___688___127___
