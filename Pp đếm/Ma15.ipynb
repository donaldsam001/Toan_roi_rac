# %%
# chỉnh hợp 8 P 5

# %%
def P(n, r):
    p = 1
    for i in range(r):
        p *= n - i
    return p

# %%
P(8,5)
# Out:
# 6720

# %%
from sympy import *
n, r = 8, 5
factorial (n) / factorial (n-r)
# Out:
# 6720
