# %%
def binomial(n, r): # To hop chập 4 của 10
    a= [1]
    for i in range( 1, n +1):
        for j in range(i -1, 0,-1):
            a[j] += a[j-1]
        a.append(1)
    return a[r]
binomial(10, 4)
# Out:
# 210
