# %%
def chinh_hop(a, k):
    if k==1:
        return  [ [i] for i in a]
    C = []
    for i,c in enumerate(a):
        b = a.copy()
        b.pop(i)
        for perm in chinh_hop(b, k-1):
            C.append([c] + perm)
    return C

# %%
''' 
Trong các chỉnh hợp chập 3 của 1, 2, 3, 4 theo thứ tự từ điển, chỉnh hợp thứ 5 là?

'''
chinh_hop(['a', 'b' , 'c','d','e'], 3)[18]
# Out:
# ['b', 'd', 'a']

# %%
def so_chinh_hop(n,k):
    if k==1:
        return n
    return n * so_chinh_hop(n-1, k-1)

# %%
'''
Có bao nhiêu cách xếp 3 vật lấy ra từ 5 vật?
'''
so_chinh_hop(6,2)  # Example call to the so_chinh_hop function with n=5 and k=3
# Out:
# 30

# %%
# chinh hop
def P(n,r): 
    p=1
    for i in range(r):
        p *=n-i
    return p
P(4,3)
# Out:
# 24
