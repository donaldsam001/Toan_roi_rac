# %%
def summands(n):
    if n == 1:
        return [[1]]
    S = []
    for i in range(1, n):
        for s in summands(n-i):
            s = [i] + S
            S.append(s)
    S.append([n])
    return S

# %%
summands(3)
# Out:
# [[1], [1, [1]], [2, [1], [1, [1]]], [3]]
