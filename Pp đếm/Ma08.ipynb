# %%
# tính n giai thừa: 8! = 40320

# %%
def factorial(n):
    p = 1
    for i in range(1, n + 1):
        p *= i
    return p

factorial(8)
# Out:
# 40320

# %%
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)

factorial(8)
# Out:
# 40320

# %%
from sympy import *
factorial(8)
# Out:
# 40320
