# %%
# ước chung nhỏ nhất
def gcd(a,b):
    while b!= 0:
        r = a% b
        a= b
        b= r
    return a

# %%
gcd(287, 91)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 gcd(287, 91)
#
# NameError: name 'gcd' is not defined

# %%
from sympy import *
gcd(287, 91)
# Out:
# 7
